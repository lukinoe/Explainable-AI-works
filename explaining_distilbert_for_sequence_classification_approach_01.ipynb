# %%
# !pip install bertviz
# !pip install ipywidgets
# Out:
# Requirement already satisfied: bertviz in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (1.2.0)
# Requirement already satisfied: requests in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from bertviz) (2.26.0)
# Requirement already satisfied: transformers>=2.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from bertviz) (4.12.5)
# Requirement already satisfied: boto3 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from bertviz) (1.20.20)
# Requirement already satisfied: sentencepiece in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from bertviz) (0.1.96)
# Requirement already satisfied: regex in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from bertviz) (2021.11.10)
# Requirement already satisfied: torch>=1.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from bertviz) (1.10.0)
# Requirement already satisfied: tqdm in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from bertviz) (4.62.3)
# Requirement already satisfied: typing-extensions in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from torch>=1.0->bertviz) (4.0.1)
# Requirement already satisfied: filelock in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from transformers>=2.0->bertviz) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from transformers>=2.0->bertviz) (0.2.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from transformers>=2.0->bertviz) (6.0)
# Requirement already satisfied: sacremoses in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from transformers>=2.0->bertviz) (0.0.46)
# Requirement already satisfied: numpy>=1.17 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from transformers>=2.0->bertviz) (1.21.4)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from transformers>=2.0->bertviz) (0.10.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from transformers>=2.0->bertviz) (21.3)
# Requirement already satisfied: colorama in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from tqdm->bertviz) (0.4.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from boto3->bertviz) (0.10.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.20 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from boto3->bertviz) (1.23.20)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from boto3->bertviz) (0.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from requests->bertviz) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from requests->bertviz) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from requests->bertviz) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from requests->bertviz) (2.0.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from botocore<1.24.0,>=1.23.20->boto3->bertviz) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from packaging>=20.0->transformers>=2.0->bertviz) (3.0.6)
# Requirement already satisfied: six in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from sacremoses->transformers>=2.0->bertviz) (1.16.0)
# Requirement already satisfied: joblib in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from sacremoses->transformers>=2.0->bertviz) (1.1.0)
# Requirement already satisfied: click in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from sacremoses->transformers>=2.0->bertviz) (8.0.3)
# Requirement already satisfied: ipywidgets in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (7.6.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipywidgets) (6.5.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipywidgets) (7.30.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.0)
# Requirement already satisfied: backcall in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipython>=4.0.0->ipywidgets) (59.4.0)
# Requirement already satisfied: colorama in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pygments in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.10.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.22)
# Requirement already satisfied: jupyter-core in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.2.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (5.4.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.5.4)
# Requirement already satisfied: pyzmq>=13 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets) (302)
# Requirement already satisfied: nbconvert in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.3.0)
# Requirement already satisfied: jinja2 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.0)
# Requirement already satisfied: argon2-cffi in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.1.0)
# Requirement already satisfied: wcwidth in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.6)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: bleach in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: testpath in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.9)
# Requirement already satisfied: defusedxml in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: pycparser in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: packaging in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: webencodings in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\annah\anaconda3\envs\xai_model_explanation\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.6)

# %%
from transformers import DistilBertTokenizerFast
from transformers import AutoModelForSequenceClassification

from bertviz import model_view
from bertviz import head_view
import numpy as np
import torch

# %% [markdown]
# <h1>Explaining Distilbert for Sequence Classifcation</h1>

# %% [markdown]
# <h2>Loading and Testing the Model</h2>
# Here we load the tokenizer and a trained model on imdb and an untrained DistilBERT model.

# %%
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')
model_trained = AutoModelForSequenceClassification.from_pretrained("textattack/distilbert-base-uncased-imdb", 
                                                                   num_labels=2, 
                                                                   output_attentions=True)

model_untrained = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", 
                                                                     num_labels=2, 
                                                                     output_attentions=True)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.bias', 'pre_classifier.weight', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# <h2>Attempt 1: Explaining the Structure of the Model with Attention over the Layers</h2>

# %%
def show_model_view(model, tokenizer, text):
    inputs = tokenizer.encode_plus(text, return_tensors='pt', add_special_tokens=True)
    input_ids = inputs['input_ids']
    
    attention = model(input_ids)[-1]
    
    input_id_list = input_ids[0].tolist() # Batch index 0
    tokens = tokenizer.convert_ids_to_tokens(input_id_list)

    model_view(attention, tokens)

# %%
def show_model_view_diff(model_trained, model_untrained, tokenizer, text):
    inputs = tokenizer.encode_plus(text, return_tensors='pt', add_special_tokens=True)
    input_ids = inputs['input_ids']
    
    attention_01 = model_trained(input_ids)[-1]
    attention_02 = model_untrained(input_ids)[-1]
    
    input_id_list = input_ids[0].tolist() # Batch index 0
    tokens = tokenizer.convert_ids_to_tokens(input_id_list)

    attention = ()

    for i in range(len(attention_01)):
        v = attention_01[i] - attention_02[i]
        attention = attention + (v,)

    model_view(attention, tokens)

# %% [markdown]
# In this attempt we visualize the attention of the models and the difference in the attention of the pretrained and untrained model to see what attention got stronger by training the model on the imdb dataset.
#
# First we define two sentences, one negative and one positive example, and see what the models would predict.

# %%
text_neg = "This movie was not really good, I did not enjoy it at all"
text_pos = "The movie was not bad at all, highly recommend"

# %%
print("Negative example text: ", text_neg)
inputs = tokenizer.encode_plus(text_neg, return_tensors='pt', add_special_tokens=True)
input_ids = inputs['input_ids']
print("Trained model predictions: ", model_trained(input_ids)['logits'])
print("Untrained model predictions: ", model_untrained(input_ids)['logits'])
# Out:
# Negative example text:  This movie was not really good, I did not enjoy it at all
# Trained model predictions:  tensor([[ 2.9077, -3.0004]], grad_fn=<AddmmBackward0>)
# Untrained model predictions:  tensor([[-0.0212,  0.1047]], grad_fn=<AddmmBackward0>)

# %%
print("Positive example text: ", text_pos)
inputs = tokenizer.encode_plus(text_pos, return_tensors='pt', add_special_tokens=True)
input_ids = inputs['input_ids']
print("Trained model predictions: ", model_trained(input_ids)['logits'])
print("Untrained model predictions: ", model_untrained(input_ids)['logits'])
# Out:
# Positive example text:  The movie was not bad at all, highly recommend
# Trained model predictions:  tensor([[-2.4866,  2.9035]], grad_fn=<AddmmBackward0>)
# Untrained model predictions:  tensor([[-0.0364,  0.1150]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# <h3>Visualize attention for each model for each sentence</h3>

# %% [markdown]
# Now we will visualize the attention for each model for each sentence to see how the attention looks like.

# %% [markdown]
# <h4>Untrained model with positive text</h4>

# %%
show_model_view(model_untrained, tokenizer, text=text_pos)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id='bertviz-a9c5b05e03ee4e668c07057e42290f43'>
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %% [markdown]
# <h4>Untrained model with negative text</h4>

# %%
show_model_view(model_untrained, tokenizer, text=text_neg)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id='bertviz-1a8b4b34390a4a86a4ec5b4efb61f310'>
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %% [markdown]
# <h4>Trained model with positive text</h4>

# %%
show_model_view(model_trained, tokenizer, text=text_pos)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id='bertviz-2fd90603d1744e0dadb9304816ec507d'>
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %% [markdown]
# <h4>Trained model with negative text</h4>

# %%
show_model_view(model_trained, tokenizer, text=text_neg)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id='bertviz-4d5c903e76b6439e92b39940fe4e77b4'>
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %% [markdown]
# <h3>Visualize attention difference between models for each sentence</h3>

# %% [markdown]
# Now we want to see what the differences are between both attention matrices and will visualize it for each sentence. Important is that it will only show positive attention, that means, that attention that got less than in the untrained model will not be visualized, only attention that got more.

# %% [markdown]
# <h4>Positive text</h4>

# %%
show_model_view_diff(model_trained, model_untrained, tokenizer, text=text_pos)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id='bertviz-dbf033cf898a4ef8a63f9dadb6a29698'>
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %% [markdown]
# <h4>Negative text</h4>

# %%
show_model_view_diff(model_trained, model_untrained, tokenizer, text=text_neg)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id='bertviz-067e5281c03448edb3123f9eb383ace1'>
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>
